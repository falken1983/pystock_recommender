# %% [markdown]
# ## 1.2 Price-Volume Data Availability Analysis
#
# As worked earlier (see [`index_componentes_webscraper`](./index_components_webscraper.ipynb) notebook), Blackrock publishes the _IVV_-ETF holdings on a monthly basis.
#
# ### Importing And Authentication
#
# In order to handle price and volume data of stocks composing S&P500 we work out first the free dataset `WIKI` which is available on the freemium Nasdaq exchange service [Nasdaq Data Link](https://data.nasdaq.com).
#
# After signing up to get a free account, we can set the necessary steps for downloading the aforementioned dataset:

# %%
#!pip install nasdaq-data-link
# add to environment.yml
# template https://github.com/binder-project/example-conda-environment/blob/master/environment.yml

# %%
## 1.2 Price-Volume Data
# Importing And Authentication 
import nasdaqdatalink
import pandas as pd
import datetime as dt
nasdaqdatalink.read_key(filename="data/.my_nq_apikey")

# %% [markdown]
# 1.  First, let we recover initial and final sample date by loading `pickle` file which contains index components:

# %%
IVV = pd.read_pickle("data/pkl/IVV_historical_components_20220727.pkl")
first_components_date = IVV.index[0]
# we substract one-year to start construction of RPMs from this point (we assume static composition from then)
first_date = first_components_date-dt.timedelta(days=365) 
first_date = first_date.strftime("%Y-%m-%d")

"""
https://data.nasdaq.com/databases/WIKIP/documentation?anchor=overview
Note: As of April 11, 2018 this data feed is no longer actively supported by the Quandl 
community. We will continue to host this data feed on Quandl, 
but we do not recommend using it for investment or analysis.
"""
wikip_last_quarter_supported = "2018-03-31" 

nasdaqdatalink.export_table('WIKI/PRICES', 
    qopts = {'columns': ['ticker', 'date', 'adj_close', 'adj_volume']}, 
    date = {'gte': first_date, 'lte': wikip_last_quarter_supported},
    filename = "data/wikip_price_volume_data.zip"
)

# %%
wikip_data = pd.read_csv("data/wikip_price_volume_data.zip", parse_dates=True)
wikip_data.head()
# Out:
#   ticker        date  adj_close  adj_volume
# 0      A  2005-09-29  22.288803   6137100.0
# 1      A  2005-09-30  22.343382   4864900.0
# 2      A  2005-10-03  22.507120   4766700.0
# 3      A  2005-10-04  22.145533   3431700.0
# 4      A  2005-10-05  21.326844   3914400.0

# %%
wikip_data.tail()
# Out:
#         ticker        date  adj_close  adj_volume
# 8461321   ZUMZ  2018-03-21      23.95    354092.0
# 8461322   ZUMZ  2018-03-22      23.35    269607.0
# 8461323   ZUMZ  2018-03-23      23.55    301584.0
# 8461324   ZUMZ  2018-03-26      24.65    375320.0
# 8461325   ZUMZ  2018-03-27      23.60    403884.0

# %% [markdown]
# 2. Let us separate the `wikip_data` by ticker symbol

# %%
# Preparing for individual CSV files 
wikip_dict = dict(tuple(wikip_data.groupby("ticker")))
#wikip_dict["AAPL"]
for ticker in wikip_dict.keys():
    wikip_dict[ticker].set_index("date", inplace=True)

# %%
wikip_dict["AAPL"]
# Out:
#            ticker     close      volume
# date
# 2005-09-29   AAPL   52.3400  22744500.0
# 2005-09-30   AAPL   53.6100  18986900.0
# 2005-10-03   AAPL   54.4400  18126900.0
# 2005-10-04   AAPL   53.7500  19266400.0
# 2005-10-05   AAPL   52.7801  21813200.0
# ...           ...       ...         ...
# 2018-03-21   AAPL  171.2700  35247358.0
# 2018-03-22   AAPL  168.8450  41051076.0
# 2018-03-23   AAPL  164.9400  40248954.0
# 2018-03-26   AAPL  172.7700  36272617.0
# 2018-03-27   AAPL  168.3400  38962839.0
#
# [3142 rows x 3 columns]

# %% [markdown]
# 3. Next, let us find which symbols of the time series index composition is not found on `WIKIP` database

# %%
print(f"# Tickers supported by WIKIP: {len(wikip_dict.keys())}")

missing_tickers = []
for row in range(0,len(IVV.index)-1):
    df_tmp = pd.DataFrame(IVV.iloc[row, 0],
        columns=["ticker","company"])
    df_tmp.index = df_tmp["ticker"]
    df_tmp.drop(columns=["ticker"], inplace=True)
    
    stock_components = df_tmp.index.unique()
    for stock in stock_components:
        if stock not in wikip_dict:
            missing_tickers.append((stock, df_tmp.loc[stock,"company"]))

print(f"# Tickers not found in WIKIP: {len(set(missing_tickers))}")
# Out:
# # Tickers supported by WIKIP: 3199
# # Tickers not found in WIKIP: 296

# %% [markdown]
# Exporting to `csv` file for reference or further use:

# %%
wikip_missing_tickers = pd.DataFrame(missing_tickers, columns=["ticker","company"])
wikip_missing_tickers.drop_duplicates(inplace=True)
wikip_missing_tickers.to_csv("data/wikip_missing_tickers.csv", index=False)
wikip_missing_tickers.head(25)
# Out:
#    ticker                             company
# 0    ANDW                        ANDREW CORP.
# 1     PGL          PEOPLES ENERGY CORPORATION
# 2    ADCT              ADC TELECOMMUNICATIONS
# 3     HPC                       HERCULES INC.
# 4   GAS.2                           NICOR INC
# 5    PMTC         PARAMETRIC TECHNOLOGY CORP.
# 6    NOVL                              NOVELL
# 7      DJ            DOW JONES & COMPANY INC.
# 8     TEK                      TEKTRONIX INC.
# 9   RSHCQ                      RS LEGACY CORP
# 10    WPI              WATSON PHARMACEUTICALS
# 11    BOL                  BAUSCH & LOMB INC.
# 12     AW        ALLIED WASTE INDUSTRIES INC.
# 13    SLR                     SOLECTRON CORP.
# 14    OMX                      OFFICEMAX INC.
# 15    FHI        FEDERATED HERMES INC CLASS B
# 16    QLG                              QLOGIC
# 17    TSG          SABRE HOLDINGS CORPORATION
# 18   MIL.                      MILLIPORE CORP
# 19   NVLS               NOVELLUS SYSTEMS INC.
# 20  CCTYQ             CIRCUIT CITY STORES INC
# 21   UNS1                 VIAVI SOLUTIONS INC
# 22  APCC.  AMERICAN POWER CONVERSION CORPORAT
# 23    SBL            SYMBOL TECHNOLOGIES INC.
# 24    HCR                     MANOR CARE INC.

# %% [markdown]
# 4. Let us find out which of the `WIKIP` unsupported tickers, are supported by _Y! Finance_ API instead.

# %%
#!pip install yfinance
# add environment.yml
import yfinance as yf

# %%
# Listed Stock behaviour
yf.Ticker("AAPL").info['regularMarketPrice'] #Apple Stock
# Out:
# 161.6295

# %%
# Delisted(Unavailable) Stock behaviour
yf.Ticker("LEH").info['regularMarketPrice']==None # The infamous Lehman Brothers
# Out:
# True

# %%
len(wikip_missing_tickers["ticker"].unique().tolist())
# Out:
# 287

# %%
from tqdm.auto import tqdm

yf_missing_tickers = []
for ticker in tqdm(wikip_missing_tickers["ticker"].unique()):
    flag = (yf.Ticker(ticker=ticker).info["regularMarketPrice"]==None)
    if flag:
        print(f"Ticker {ticker} not Found: Appending...")
        yf_missing_tickers.append(ticker)
len(set(yf_missing_tickers))
# Out:
#   0%|          | 0/287 [00:00<?, ?it/s]
# Ticker ANDW not Found: Appending...
# Ticker PGL not Found: Appending...
# Ticker HPC not Found: Appending...
# Ticker GAS.2 not Found: Appending...
# Ticker PMTC not Found: Appending...
# Ticker NOVL not Found: Appending...
# Ticker DJ not Found: Appending...
# Ticker TEK not Found: Appending...
# Ticker RSHCQ not Found: Appending...
# Ticker WPI not Found: Appending...
# Ticker BOL not Found: Appending...
# Ticker AW not Found: Appending...
# Ticker SLR not Found: Appending...
# Ticker OMX not Found: Appending...
# Ticker QLG not Found: Appending...
# Ticker TSG not Found: Appending...
# Ticker MIL. not Found: Appending...
# Ticker NVLS not Found: Appending...
# Ticker CCTYQ not Found: Appending...
# Ticker UNS1 not Found: Appending...
# Ticker APCC. not Found: Appending...
# Ticker SBL not Found: Appending...
# Ticker HCR not Found: Appending...
# Ticker AHEB GR not Found: Appending...
# Ticker PTV not Found: Appending...
# Ticker FNP not Found: Appending...
# Ticker KG not Found: Appending...
# Ticker DG.1 not Found: Appending...
# Ticker CMVT not Found: Appending...
# Ticker TIN not Found: Appending...
# Ticker PBG not Found: Appending...
# Ticker TLAB not Found: Appending...
# Ticker GR not Found: Appending...
# Ticker AV.1 not Found: Appending...
# Ticker RX not Found: Appending...
# Ticker BRL not Found: Appending...
# Ticker MOLX not Found: Appending...
# Ticker WYND not Found: Appending...
# Ticker BMC not Found: Appending...
# Ticker H.4 not Found: Appending...
# Ticker BDK not Found: Appending...
# Ticker BFB not Found: Appending...
# Ticker ABI not Found: Appending...
# Ticker ACS not Found: Appending...
# Ticker CTX not Found: Appending...
# Ticker TRB not Found: Appending...
# Ticker EKDKQ not Found: Appending...
# Ticker AYE not Found: Appending...
# Ticker UUM not Found: Appending...
# Ticker ROH not Found: Appending...
# Ticker MEDI not Found: Appending...
# Ticker NSM.2 not Found: Appending...
# Ticker USX1 not Found: Appending...
# Ticker KSE not Found: Appending...
# Ticker CBSS not Found: Appending...
# Ticker ASD not Found: Appending...
# Ticker SOV not Found: Appending...
# Ticker CBE not Found: Appending...
# Ticker WEN.2 not Found: Appending...
# Ticker BMET not Found: Appending...
# Ticker CVH not Found: Appending...
# Ticker UVN not Found: Appending...
# Ticker ABKFQ not Found: Appending...
# Ticker UST.1 not Found: Appending...
# Ticker BJS not Found: Appending...
# Ticker LTD not Found: Appending...
# Ticker CITGQ not Found: Appending...
# Ticker FSH not Found: Appending...
# Ticker ASO.1 not Found: Appending...
# Ticker WWY not Found: Appending...
# Ticker FCX* not Found: Appending...
# Ticker KMI.1 not Found: Appending...
# Ticker FO not Found: Appending...
# Ticker PGN not Found: Appending...
# Ticker ASN not Found: Appending...
# Ticker SLE not Found: Appending...
# Ticker MI not Found: Appending...
# Ticker HET not Found: Appending...
# Ticker EDS. not Found: Appending...
# Ticker NFB not Found: Appending...
# Ticker HNZ not Found: Appending...
# Ticker QWST not Found: Appending...
# Ticker EOP not Found: Appending...
# Ticker SCN not Found: Appending...
# Ticker CCU.1 not Found: Appending...
# Ticker WFT not Found: Appending...
# Ticker CPPRQ not Found: Appending...
# Ticker FSL.B not Found: Appending...
# Ticker XTO not Found: Appending...
# Ticker MEL not Found: Appending...
# Ticker RN7 not Found: Appending...
# Ticker BSC.1 not Found: Appending...
# Ticker AG4 not Found: Appending...
# Ticker MX4A not Found: Appending...
# Ticker LTR not Found: Appending...
# Ticker GENZ not Found: Appending...
# Ticker MHS not Found: Appending...
# Ticker SWG not Found: Appending...
# Ticker MTLQQ not Found: Appending...
# Ticker AAZ not Found: Appending...
# Ticker GDW not Found: Appending...
# Ticker HCA.2 not Found: Appending...
# Ticker RTN1 not Found: Appending...
# Ticker CFC not Found: Appending...
# Ticker AT. not Found: Appending...
# Ticker NCC not Found: Appending...
# Ticker 8686 not Found: Appending...
# Ticker NTH not Found: Appending...
# Ticker CMX not Found: Appending...
# Ticker ADM* not Found: Appending...
# Ticker BNI not Found: Appending...
# Ticker TXU not Found: Appending...
# Ticker LOM not Found: Appending...
# Ticker AABA not Found: Appending...
# Ticker FDC not Found: Appending...
# Ticker PA9 not Found: Appending...
# Ticker BUD.2 not Found: Appending...
# Ticker PRU* not Found: Appending...
# Ticker LEHMQ not Found: Appending...
# Ticker WAMUQ not Found: Appending...
# Ticker MWZ not Found: Appending...
# Ticker QCI not Found: Appending...
# Ticker MOT not Found: Appending...
# Ticker AAPL* not Found: Appending...
# Ticker AEC1 not Found: Appending...
# Ticker WYE not Found: Appending...
# Ticker MER not Found: Appending...
# Ticker SLBA not Found: Appending...
# Ticker BLS not Found: Appending...
# Ticker WFC* not Found: Appending...
# Ticker AIG* not Found: Appending...
# Ticker 0R01 not Found: Appending...
# Ticker GEC not Found: Appending...
# Ticker DYNIQ not Found: Appending...
# Ticker KFT not Found: Appending...
# Ticker WFR not Found: Appending...
# Ticker DC7 not Found: Appending...
# Ticker TIE not Found: Appending...
# Ticker NYX not Found: Appending...
# Ticker MV not Found: Appending...
# Ticker MEE not Found: Appending...
# Ticker CEPH not Found: Appending...
# Ticker MFE not Found: Appending...
# Ticker DOFSQ not Found: Appending...
# Ticker XTSLA not Found: Appending...
# Ticker T3W1 not Found: Appending...
# Ticker TWX* not Found: Appending...
# Ticker PCS not Found: Appending...
# Ticker VISA not Found: Appending...
# Ticker BRKB not Found: Appending...
# Ticker - not Found: Appending...
# Ticker ANRZQ not Found: Appending...
# Ticker MPN not Found: Appending...
# Ticker MOS* not Found: Appending...
# Ticker OSHWQ not Found: Appending...
# Ticker OSHSQ not Found: Appending...
# Ticker 6COP not Found: Appending...
# Ticker 4XS not Found: Appending...
# Ticker KMI WS not Found: Appending...
# Ticker THC1 not Found: Appending...
# Ticker 3EC not Found: Appending...
# Ticker VX1 not Found: Appending...
# Ticker A60 not Found: Appending...
# Ticker NEBLQ not Found: Appending...
# Ticker FB* not Found: Appending...
# Ticker GGQ7 not Found: Appending...
# Ticker HAWKB not Found: Appending...
# Ticker WPG not Found: Appending...
# Ticker MNKKQ not Found: Appending...
# Ticker BLKFDS not Found: Appending...
# Ticker BF/B not Found: Appending...
# Ticker UBSFT not Found: Appending...
# Ticker ESZ4 not Found: Appending...
# Ticker ESH5 not Found: Appending...
# Ticker ESM5 not Found: Appending...
# Ticker BF.B not Found: Appending...
# Ticker ESU5 not Found: Appending...
# Ticker BLD WI not Found: Appending...
# Ticker CC WI not Found: Appending...
# Ticker ESZ5 not Found: Appending...
# Ticker UBFUT not Found: Appending...
# Ticker SYF-W not Found: Appending...
# Ticker ESH6 not Found: Appending...
# Ticker ESM6 not Found: Appending...
# Ticker UAC/C not Found: Appending...
# Ticker ESU6 not Found: Appending...
# Ticker ESZ6 not Found: Appending...
# Ticker ESH7 not Found: Appending...
# Ticker ESU7 not Found: Appending...
# Ticker MARGIN_USD not Found: Appending...
# Ticker ESZ7 not Found: Appending...
# Ticker ESH8 not Found: Appending...
# Ticker ESM8 not Found: Appending...
# Ticker ESU8 not Found: Appending...
# Ticker ESZ8 not Found: Appending...
# Ticker ESH9 not Found: Appending...
# Ticker ESM9 not Found: Appending...
# Ticker ESU9 not Found: Appending...
# Ticker ESZ9 not Found: Appending...
# Ticker DISHR not Found: Appending...
# Ticker VIAC not Found: Appending...
# Ticker ESH0 not Found: Appending...
# Ticker ESM0 not Found: Appending...
# Ticker TMUSR not Found: Appending...
# Ticker ESU0 not Found: Appending...
# Ticker OXY WS WI not Found: Appending...
# Ticker ESZ0 not Found: Appending...
# Ticker ESH1 not Found: Appending...
# Ticker ESM1 not Found: Appending...
# Ticker ESU1 not Found: Appending...
# Ticker ESZ1 not Found: Appending...
# Ticker ESH2 not Found: Appending...
# Ticker ESM2 not Found: Appending...
# Ticker ESU2 not Found: Appending...
# 214

# %%
yf_missing_tickers = pd.DataFrame(yf_missing_tickers, columns=["ticker"]).drop_duplicates()
yf_missing_tickers.nunique()
# Out:
# ticker    214
# dtype: int64

# %%
# 214 Tickers Still Missing
yf_missing_tickers.to_csv("data/yf_missing_tickers.csv")

# %%
"""
Based upon `yf_missing_tickers.csv` and some handmade web intelligence we
elaborate the final missing data csv file
"""
missing_data = pd.read_csv("data/abnormal_ticker_to_analyze.csv",
index_col="ticker")
missing_data[missing_data["new_ticker"].notna()]
# Out:
#        yfinance_condition new_ticker
# ticker
# PMTC        ticker_change        PTC
# WPI              delisted       ABBV
# AW               delisted        RSG
# SLR              delisted       FLEX
# TSG         ticker_change       SABR
# UNS1        ticker_change       VIAV
# BFB         ticker_change       BF_B
# UUM         ticker_change        UNM
# USX1        ticker_change          X
# LTD         ticker_change         LB
# HNZ         ticker_change        KHC
# RN7         ticker_change         RF
# AG4         ticker_change        AGN
# MX4A        ticker_change        CME
# LTR         ticker_change          L
# SWG         ticker_change       SCHW
# AAZ         ticker_change        APC
# 8686        ticker_change        AFL
# NTH         ticker_change        NOC
# LOM         ticker_change        LMT
# PA9         ticker_change        TRV
# MWZ         ticker_change        MET
# QCI         ticker_change       QCOM
# SLBA        ticker_change        SLB
# DC7         ticker_change        DFS
# VISA        ticker_change          V
# -           ticker_change      LPRAX
# MPN         ticker_change        MPC
# 4XS         ticker_change       ESRX
# GGQ7        ticker_change       GOOG
# BF/B        ticker_change       BF_B
# UBSFT       ticker_change      UBSFY
# BF.B        ticker_change       BF_B
# BLD WI      ticker_change        BLD
# CC WI       ticker_change         CC
# SYF-W       ticker_change        SYF
# UAC/C       ticker_change        UAA

# %%
""" 
35 stocks are potentially available from Y! Finance:
 - The most of the companies have changed ticker and long tseries are available.
 - 3 stocks that were delisted can be assimilated to their buyers (IPOs)
"""
ticker_transition_data = missing_data[missing_data["new_ticker"].notna()]
ticker_transition_data["new_ticker"].nunique()
# Out:
# 35

# %%
"""
The fund managers of IVV ETF have the mandate to invest more than 90% in S&P500 stock components.
Futures and some cash had also been ocasionally managed
"""
nonstock_tickers = missing_data.loc[missing_data["yfinance_condition"].str.contains("non_stock"),:]
nonstock_tickers
# Out:
#            yfinance_condition new_ticker
# ticker
# ESZ4                non_stock        NaN
# ESH5                non_stock        NaN
# ESM5                non_stock        NaN
# ESU5                non_stock        NaN
# ESZ5                non_stock        NaN
# UBFUT               non_stock        NaN
# ESH6                non_stock        NaN
# ESM6                non_stock        NaN
# ESU6                non_stock        NaN
# ESZ6                non_stock        NaN
# ESH7                non_stock        NaN
# ESU7                non_stock        NaN
# MARGIN_USD          non_stock        NaN
# ESZ7                non_stock        NaN
# ESH8                non_stock        NaN
# ESM8                non_stock        NaN
# ESU8                non_stock        NaN
# ESZ8                non_stock        NaN
# ESH9                non_stock        NaN
# ESM9                non_stock        NaN
# ESU9                non_stock        NaN
# ESZ9                non_stock        NaN
# ESH0                non_stock        NaN
# ESM0                non_stock        NaN
# ESU0                non_stock        NaN
# ESZ0                non_stock        NaN
# ESH1                non_stock        NaN
# ESM1                non_stock        NaN
# ESU1                non_stock        NaN
# ESZ1                non_stock        NaN
# ESH2                non_stock        NaN
# ESM2                non_stock        NaN
# ESU2                non_stock        NaN

# %%
len(nonstock_tickers.index)
# Out:
# 33

# %% [markdown]
# Therefore:

# %%
# Tickers that are not under the WIKIP/YFinance scope
print(yf_missing_tickers.nunique()-(ticker_transition_data["new_ticker"].nunique()+len(nonstock_tickers)) )
# Out:
# ticker    146
# dtype: int64

# %%
ticker_special_char = yf_missing_tickers[yf_missing_tickers["ticker"].str.contains("\*")]
ticker_special_char["ticker"]
# Out:
# 70      FCX*
# 109     ADM*
# 117     PRU*
# 123    AAPL*
# 129     WFC*
# 130     AIG*
# 146     TWX*
# 153     MOS*
# 164      FB*
# Name: ticker, dtype: object

# %%
lst_ticker_special_char = ticker_special_char["ticker"].str.strip("*").tolist()
lst_ticker_special_char
# Out:
# ['FCX', 'ADM', 'PRU', 'AAPL', 'WFC', 'AIG', 'TWX', 'MOS', 'FB']

# %%
# Some residual missing tickers can also be fixed by dropping special characters
# e.g. FB (also downloadable via META)
for symbol in lst_ticker_special_char:
    yf.download(symbol, start="2022-7-28", end="2022-7-29")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - TWX: No data found for this date range, symbol may be delisted
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
historical_sp500_tickers_set = set()

for row in tqdm(range(0,len(IVV.index)-1)):
    df_tmp = pd.DataFrame(IVV.iloc[row, 0],
        columns=["ticker","company"])
    lst_running_set = df_tmp["ticker"].tolist()
    historical_sp500_tickers_set.update(lst_running_set)
# Out:
#   0%|          | 0/185 [00:00<?, ?it/s]

# %%
print(historical_sp500_tickers_set)
# Out:
# {'CBH', 'ROL', 'FHN', 'FRX', 'ESM0', 'BCR', 'ETFC', 'HFC', 'FCX*', 'NWS', 'RX', 'GGP', 'CF', 'CCE', 'L', 'TDY', 'WDC', 'CTSH', 'JWN', 'DRI', 'BMET', 'CHD', 'KDP', 'APOL', 'SNI', 'RMD', 'PBI', 'XRAY', 'ANSS', 'XOM', 'NXPI', 'KMI.1', 'GLW', 'JNJ', 'NTH', 'SYK', 'VZ', 'ESH0', 'MWV', 'MSFT', 'VMC', 'SPG', 'J', 'K', 'LRCX', 'STJ', 'AAPL', 'DISCK', 'SBAC', 'MHFI', 'ESM8', 'UVN', 'NTAP', 'ESM1', 'TSG', 'CHTR', 'PTV', 'JNPR', 'ESRX', 'DO', 'NOW', 'LUV', 'CPPRQ', 'MRNA', 'NOVL', 'CME', 'EMR', 'DTV', 'SUN', 'ISRG', 'TMO', 'SEDG', 'CPWR', 'DEN', 'AIV', 'MAC', 'SLG', 'HOG', 'ABC', 'LNT', 'DOV', 'AAP', 'AV.1', '3EC', 'WTW', 'WB', 'GNW', 'CMCSK', 'VRSN', 'IR', 'TWX*', '6COP', 'AAL', 'RE', 'ON', 'DPZ', 'BNI', 'NVLS', 'CA', 'KIM', 'ESM6', 'MBI', 'JCI', 'CAM', 'BF.B', 'EMC', 'FFIV', 'APD', 'CPRT', 'FOXA', 'FOSL', 'STI', 'ESU6', 'PCS', 'V', 'ACS', 'NE', 'ADP', 'SHLDQ', 'FO', 'BOL', 'ETR', 'CEPH', 'CLF', 'BLD WI', 'AMZN', 'DELL', 'XRX', 'CC WI', 'TXT', 'F', 'SNV', 'THC', 'WYE', 'HON', 'CSC', 'UBSFT', 'CFN', 'DLR', 'EPAM', 'LOM', 'PNR', 'NUE', 'VX1', 'MET', 'ORCL', 'URBN', 'FHI', 'WCG', 'AOS', 'NEBLQ', 'MAS', 'DOW', 'CLX', 'INTC', 'KLAC', 'RSG', 'ADSK', 'MCO', 'DUK', 'BUD.2', 'MOLX', 'MCK', 'UNH', 'YHOO', 'DWDP', 'ESZ1', 'HII', 'COP', 'HSP', 'EXPD', 'WLP', 'GRMN', 'HAS', 'GL', 'LMT', 'FSL.B', 'WLTW', 'AON', 'UNP', 'MIL.', 'FNP', 'SNDK', 'RTX', 'DJ', 'BEAM', 'BXLT', 'GOOG', 'IVZ', 'CERN', 'PFE', 'TDC', 'MPN', 'LUK', 'CVH', 'PYPL', 'BKNG', 'GENZ', 'DVN', 'FAST', 'OSHWQ', 'TE', 'CBE', 'UTX', 'KFT', 'NFX', 'ROK', 'MJN', 'ESM9', 'R', '-', 'NKTR', 'ESH1', 'KMB', 'IBM', 'ADM', 'ESZ0', 'GR', 'COO', 'DNB', 'HBI', 'VRSK', 'ASD', 'NAV', 'MX4A', 'BBY', 'PETM', 'UHS', 'ESZ4', 'CNC', 'SWG', 'TMUS', 'JBHT', 'VRTX', 'MYL', 'MCD', 'BLKFDS', 'PDCO', 'AYE', 'NBR', 'CARR', 'LYB', 'MOS', 'GHC', 'WPX', 'USB', 'LTR', 'YUM', 'POOL', 'ANTM', 'CIEN', 'MMM', 'DG.1', 'C', 'IP', 'IT', 'XL', 'EKDKQ', 'DTE', 'PGN', 'LKQ', 'NOV', 'RJF', 'PCG', 'ANET', 'ARG', 'REGN', 'NRG', 'LEG', 'ACAS', 'ESH5', 'ADCT', 'TRB', 'ESU0', 'CBOE', 'DISHR', 'CI', 'PTC', 'AABA', 'RN7', 'CEG', 'BALL', 'IAC', 'AKAM', 'GD', 'AFL', 'FCX', 'PXD', 'PMTC', 'KG', 'EIX', 'LUMN', 'MAR', 'HD', 'NFLX', 'BTI', 'JOY', 'MHK', 'RRC', 'RF', 'EXR', 'OXY WS WI', 'CTRA', 'TMUSR', 'ABI', 'ESZ8', 'TECH', 'NFB', 'BDK', 'NTRS', 'HSIC', 'MNST', 'TSO', 'DC7', 'COH', 'S', 'FNMA', 'MTW', 'BHGE', 'GS', 'ENPH', 'SPGI', 'SLE', 'LU', 'RIG', 'XEL', 'TEG', 'DXCM', 'AW', 'XLNX', 'AN', 'BK', 'AAZ', 'ANF', 'GME', 'BLK', 'CPB', 'PX', 'WM', 'QLG', 'WFC*', 'PPL', 'TEX', 'RL', 'KRFT', 'HBAN', 'BF/B', 'WELL', 'FTNT', 'WU', 'KO', 'GCI', 'UPS', 'LLY', 'JEF', 'KEY', 'PNW', 'AG4', 'MV', 'APH', 'EP', 'HRL', 'ALGN', 'JNS', 'USX1', 'AEP', 'CL', 'IGT', 'CMVT', 'PGR', 'AVGO', 'OTIS', 'MMI', 'LH', 'DAL', 'TGT', 'ITW', 'ACT', 'WEN', 'SANM', 'IQV', 'ROH', 'JBL', 'BTU', 'UA', 'CHRW', 'EQT', 'DXC', 'BBWI', 'CTVA', 'GE', 'CMS', 'NBL', 'MI', 'WRB', 'INCO', 'MDP', 'KSE', 'D', 'CCI', 'ES', 'HRB', 'DHI', 'ESZ7', 'WAMUQ', 'APTV', 'UAC/C', 'JEC', 'CRM', 'AXP', 'ZION', 'GIS', 'SPLS', 'ATO', 'ALL', 'DPS', 'CBS', 'VISA', 'LVS', 'SWKS', 'BSX', 'AYI', 'BIO', 'HMA', 'AEE', 'NU', 'GPS', 'EL', 'LEHMQ', 'SJM', 'BWA', 'KORS', 'MNKKQ', 'XEC', 'MTD', 'MFE', 'WIN', 'LPX', 'QCI', 'ZTS', 'STE', 'KBH', 'PA9', 'NSM.2', 'BLS', 'HCN', 'WPI', 'INCY', 'CTAS', 'FDX', 'BEN', 'KHC', 'DISH', 'SSP', 'CRL', 'MEL', 'PAYC', 'EBAY', 'KMI WS', 'A60', 'PAYX', 'PBG', 'DNR', 'DRE', 'SIVB', 'ETSY', 'ADBE', 'HST', 'ESM5', 'GILD', 'PSX', 'UNS1', 'SNPS', 'H.4', 'CAT', 'CE', 'MTCH', 'UNM', 'STX', 'NLSN', 'LNC', 'NCC', 'WFM', 'AWK', 'SNA', 'ABMD', 'NEM', 'ESU9', 'WFC', 'GEC', 'DDR', 'ABT', 'JPM', 'NKE', 'ESZ5', 'ILMN', 'MKTX', 'EDS.', 'HCP', 'HES', 'Q', 'AMCR', 'LTD', 'NDAQ', 'TRIP', 'GM', 'PKI', 'MEDI', 'ESV', 'LM', 'AME', 'CTLT', 'KSS', 'WHR', 'FOX', 'AGN', 'STZ', 'ALTR', 'ABKFQ', 'FDC', 'ESU7', 'BSC.1', 'SRCL', 'VIAC', 'UDR', 'SAF', 'T3W1', 'LLL', 'ADM*', 'DD', 'OXY', 'KMX', 'URI', 'CZR', 'CHK', 'CITGQ', 'PKG', 'OI', 'KR', 'AMGN', 'WBA', 'CVC', 'ESM2', 'PCP', 'ADI', 'WFR', 'ICE', 'ANRZQ', 'EVHC', 'K ...

# %%
print(f"# Historical Tickers composing S&P500 cached from BlackRock public information: {len(historical_sp500_tickers_set)}")
# Out:
# # Historical Tickers composing S&P500 cached from BlackRock public information: 1008

# %% [markdown]
# After all we have a reasonable minimum ~90% of tickers at disposal for the entire sample under consideration. However some further analysis

# %%
print(f"{100 - 100* 140 / len(historical_sp500_tickers_set)}% tickers all-times supported")
